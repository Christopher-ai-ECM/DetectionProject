# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/Codes/
# Out:
# /content/gdrive/.shortcut-targets-by-id/19PNzLYtEQXL31bnSI4OmM-F6sGEXOPvV/Codes

# %%
#Configurer son compte
# !git config user.email "h8799r@gmail.com"
# !git config user.name "CodingWand"

# %%
#Mettre son token perso ici
git_token = "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";
#Relier le projet au dépot en ligne
#ATTENTION : penser à mettre le bon lien HTTPS
# !git remote add origin https://{git_token}@github.com/Christopher-ai-ECM/DetectionProject.git
# Out:
# fatal: remote origin already exists.

# %%
#Ajouter tous les fichiers qui ont changés
# !git add .

# %%
#Commit, modifier le message
# !git commit -m "First commit"
# Out:
# [master 570cadb] First commit
#  4 files changed, 4 insertions(+), 3 deletions(-)
#  create mode 100644 GitComm.ipynb
#  rewrite projot-lea.ipynb (76%)

# %%
#Push dans github
# !git push --set-upstream origin master
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
