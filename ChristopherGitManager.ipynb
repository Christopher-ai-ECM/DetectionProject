# %%
#Pour pousser vos modifications vers github il vous suffit d'éxecuter entièrement ce notebook
#Pensez à créer votre AccessToken github avant toutefois
#Si vous avez des questions, contactez Assane Diouf
import getpass
#On mount gdrive pour accéder au dossiers mis en raccourci
#Si le dossier du projet est dans votre drive, vous pouvez mount content/drive ou laisser content/gdrive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
#On va dans le projet
#Mettre le nom du dossier du projet à la place de Code
# %cd gdrive/MyDrive/Codes

# %%
uEmail = str(input("Entrez votre adresse email : "))
userName = str(input("Entrez votre username : "))
#Configurer son compte
# !git config user.email uEmail
# !git config user.name  userName

# %%
#Mettre son token perso ici
git_token = getpass.getpass()
#Relier le projet au dépot en ligne
#ATTENTION : penser à mettre le bon lien HTTPS
# !git remote set-url origin https://{git_token}@github.com/Christopher-ai-ECM/DetectionProject.git

# %%
#Ajouter tous les fichiers qui ont changés
# !git add .

# %%
commitMessage = str(input("Entrez votre message de commit : "))
#Commit, modifier le message
# !git commit -m commitMessage

# %%
#Push dans github
# !git push --set-upstream origin master
